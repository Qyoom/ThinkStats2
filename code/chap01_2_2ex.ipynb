# %% [markdown]
# [RW: This is a test to troubleshoot why I was having problems importing newly placed functions in nsfg module. So far it looks like the problem has to do with something about the different between Python2 and Python3. This file uses Python3 and will not recognize the newly created function. See file chap01_2_1 which uses Python 2 and imports the new function successfully. Although I have so far located this discrepancy between the versions, I do not as yet have a real understanding of the underlying reason for the error nor how to remedy. For the time being, just to move forward with the material in the textbook, I will stay with using Python2 in the notebooks. Note that Spyder (which I'm using to code and test the module) is running Python3. There is much more I need to learn about managing and coordinating my/the Python environment. I should at least pose a question on StackExchange.]

# %%
from __future__ import print_function, division

import nsfg # fsfg is a module (i.e. .py code file)
import nsfg_rw1

# %%
preg = nsfg.ReadFemPreg()
preg.head()
# Out:
#    caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0       1         1        NaN        NaN       NaN       NaN       6.0
# 1       1         2        NaN        NaN       NaN       NaN       6.0
# 2       2         1        NaN        NaN       NaN       NaN       5.0
# 3       2         2        NaN        NaN       NaN       NaN       6.0
# 4       2         3        NaN        NaN       NaN       NaN       6.0
#
#    pregend2  nbrnaliv  multbrth     ...       laborfor_i  religion_i  metro_i  \
# 0       NaN       1.0       NaN     ...                0           0        0
# 1       NaN       1.0       NaN     ...                0           0        0
# 2       NaN       3.0       5.0     ...                0           0        0
# 3       NaN       1.0       NaN     ...                0           0        0
# 4       NaN       1.0       NaN     ...                0           0        0
#
# ...

# %%
preg = nsfg_rw1.ReadFemPreg()
preg.head()
# Out:
#    caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0       1         1        NaN        NaN       NaN       NaN       6.0
# 1       1         2        NaN        NaN       NaN       NaN       6.0
# 2       2         1        NaN        NaN       NaN       NaN       5.0
# 3       2         2        NaN        NaN       NaN       NaN       6.0
# 4       2         3        NaN        NaN       NaN       NaN       6.0
#
#    pregend2  nbrnaliv  multbrth     ...       laborfor_i  religion_i  metro_i  \
# 0       NaN       1.0       NaN     ...                0           0        0
# 1       NaN       1.0       NaN     ...                0           0        0
# 2       NaN       3.0       5.0     ...                0           0        0
# 3       NaN       1.0       NaN     ...                0           0        0
# 4       NaN       1.0       NaN     ...                0           0        0
#
# ...

# %%
t1 = nsfg_rw1.test1()
t1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-ff2472e129c4> in <module>()
# ----> 1 t1 = nsfg_rw1.test1()
#       2 t1
#
# AttributeError: module 'nsfg_rw1' has no attribute 'test1'
